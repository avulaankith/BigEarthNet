# %%
# importing libraries
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob

import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

import rasterio as rio

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

import plotly.graph_objects as go

np.seterr(divide='ignore', invalid='ignore')

### Each image has a different size.
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
folder_path = "S2A_MSIL2A_20170613T101031_0_59/"

S_sentinel_bands = glob(folder_path+"/*B?*.tif")
S_sentinel_bands.sort()

l = []
print("All the available bands with their shapes: ")
for i in S_sentinel_bands:
  with rio.open(i, 'r') as f:
    l.append(f.read(1))
for idx, i in enumerate(l):
    if idx+1 < 10:
        print(f"B0{idx+1}:  {i.shape}")
    else:
        print(f"B{idx+1}:  {i.shape}")
# Out:
# All the available bands with their shapes:
# B01:  (20, 20)
# B02:  (120, 120)
# B03:  (120, 120)
# B04:  (120, 120)
# B05:  (60, 60)
# B06:  (60, 60)
# B07:  (60, 60)
# B08:  (120, 120)
# B09:  (20, 20)
# B10:  (60, 60)
# B11:  (60, 60)
# B12:  (60, 60)

# %%
data = json.load(open('S2A_MSIL2A_20170613T101031_0_59/S2A_MSIL2A_20170613T101031_0_59_labels_metadata.json'))
print(data)

folder_path = "S2A_MSIL2A_20170613T101031_0_59/"

S_sentinel_bands = glob(folder_path+"/*B?*.tif")
S_sentinel_bands.sort()

l = []

for i in S_sentinel_bands:
  with rio.open(i, 'r') as f:
    l.append(f.read(1))
for i in l:
    print(i.shape)

rgb_l = l[1:4]
arr_st = np.stack(rgb_l)
print(arr_st.shape)

# RGB Composite Image

rgb = ep.plot_rgb(arr_st, 
                  rgb=(2,1,0), 
                  figsize=(10, 16))
plt.show()

# RGB Composite Image with Strech

ep.plot_rgb(arr_st,
            rgb=(2, 1, 0),
            stretch=True,
            str_clip=0.2,
            figsize=(10, 16))
plt.show()
# Out:
# {'labels': ['Sea and ocean'], 'coordinates': {'ulx': 499980, 'uly': 7029240, 'lrx': 501180, 'lry': 7028040}, 'projection': 'PROJCS["WGS 84 / UTM zone 34N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",21],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32634"]]', 'tile_source': 'S2A_MSIL1C_20170613T101031_N0205_R022_T34VER_20170613T101025.SAFE', 'acquisition_date': '2017-06-13 10:10:31'}
# (20, 20)
# (120, 120)
# (120, 120)
# (120, 120)
# (60, 60)
# (60, 60)
# (60, 60)
# (120, 120)
# ...

# %%
ep.plot_bands(arr_st, 
              cmap = 'gist_earth', 
              figsize = (20, 12), 
              cols = 6, 
              cbar = False)
plt.show()

# %%
data = json.load(open('S2A_MSIL2A_20170613T101031_0_63/S2A_MSIL2A_20170613T101031_0_63_labels_metadata.json'))
print(data)

folder_path = "S2A_MSIL2A_20170613T101031_0_63/"

S_sentinel_bands = glob(folder_path+"/*B?*.tif")
S_sentinel_bands.sort()

l = []

for i in S_sentinel_bands:
  with rio.open(i, 'r') as f:
    l.append(f.read(1))
for i in l:
    print(i.shape)

rgb_l = l[1:4]
arr_st = np.stack(rgb_l)
print(arr_st.shape)
# RGB Composite Image
rgb = ep.plot_rgb(arr_st, 
                  rgb=(2,1,0), 
                  figsize=(10, 16))
plt.show()

# RGB Composite Image with Strech

ep.plot_rgb(arr_st,
            rgb=(2, 1, 0),
            stretch=True,
            str_clip=0.2,
            figsize=(10, 16))
plt.show()
# Out:
# {'labels': ['Sea and ocean'], 'coordinates': {'ulx': 499980, 'uly': 7024440, 'lrx': 501180, 'lry': 7023240}, 'projection': 'PROJCS["WGS 84 / UTM zone 34N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",21],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32634"]]', 'tile_source': 'S2A_MSIL1C_20170613T101031_N0205_R022_T34VER_20170613T101025.SAFE', 'acquisition_date': '2017-06-13 10:10:31'}
# (20, 20)
# (120, 120)
# (120, 120)
# (120, 120)
# (60, 60)
# (60, 60)
# (60, 60)
# (120, 120)
# ...

# %%
ep.plot_bands(arr_st, 
              cmap = 'gist_earth', 
              figsize = (20, 12), 
              cols = 6, 
              cbar = False)
plt.show()

# %%
data = json.load(open('S2A_MSIL2A_20170613T101031_9_59/S2A_MSIL2A_20170613T101031_9_59_labels_metadata.json'))
print(data)

folder_path = "S2A_MSIL2A_20170613T101031_9_59/"

S_sentinel_bands = glob(folder_path+"/*B?*.tif")
S_sentinel_bands.sort()

l = []

for i in S_sentinel_bands:
  with rio.open(i, 'r') as f:
    l.append(f.read(1))
for i in l:
    print(i.shape)

rgb_l = l[1:4]
arr_st = np.stack(rgb_l)
print(arr_st.shape)
# RGB Composite Image
rgb = ep.plot_rgb(arr_st, 
                  rgb=(2,1,0), 
                  figsize=(10, 16))
plt.show()

# RGB Composite Image with Strech

ep.plot_rgb(arr_st,
            rgb=(2, 1, 0),
            stretch=True,
            str_clip=0.2,
            figsize=(10, 16))
plt.show()
# Out:
# {'labels': ['Coniferous forest', 'Mixed forest', 'Sea and ocean'], 'coordinates': {'ulx': 510780, 'uly': 7029240, 'lrx': 511980, 'lry': 7028040}, 'projection': 'PROJCS["WGS 84 / UTM zone 34N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",21],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32634"]]', 'tile_source': 'S2A_MSIL1C_20170613T101031_N0205_R022_T34VER_20170613T101025.SAFE', 'acquisition_date': '2017-06-13 10:10:31'}
# (20, 20)
# (120, 120)
# (120, 120)
# (120, 120)
# (60, 60)
# ...
